# %%
array = ["水","金","地","火","木","土","天","海","冥"]

a = 0
for i in array:
  print(i)
while a < 8:
  a = a + 1
  print(array[a])
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
